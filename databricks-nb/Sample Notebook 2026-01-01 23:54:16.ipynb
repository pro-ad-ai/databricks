# %% [markdown]
# This is my First Text

# %%
df = spark.table('orders')
display(df)

# %%
# %sql
-- Just for Querying the data or viewing it and not performing any transformations then you should use the sql query editor

select * from orders

# %%
# %sql
select * from samples.bakehouse.sales_transactions
